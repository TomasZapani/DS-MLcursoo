# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Es un gráfico bastante conocido y facil de realizar

# %% [markdown]
# Creamos el df para el ej

# %%
df = pd.DataFrame({
    'etiquetas':['Manzanas','Bananas','Naranjas','Uvas'],
    'cant':[40,32,20,14]
})

df
# Out:
#   etiquetas  cant
# 0  Manzanas    40
# 1   Bananas    32
# 2  Naranjas    20
# 3      Uvas    14

# %%
Graficamos la torta de este una serie de este df

# %%
plt.pie(df['cant']);#El método para graf el pastel es .pie()

# %% [markdown]
# Manejo de parámetro con el gráf circular

# %%
#Mostrar las etiquetas en el pastel para dif, con el param label
plt.pie(df['cant'],labels=df['etiquetas']);#Le pasamos a labels que queremos mostrar, dandole la serie de etiquetas del df

# %%
#Vamos a ver los porcentajes del pastel con el param autopct
plt.pie(df['cant'],labels=df['etiquetas'],autopct='%1.1f%%');#Le pasamos a autopct la forma de como queremos que se vea el porcent, hay que poner los dos %%, dps en el medio se pone el 1.1%, donde el el primer 1 es el numero entero y segundo 1 es para que vea que quiero solo un decimal dps del punto,la f obvio es de float y el % que está adentro indica que queremos que estos porcentajes se vean con su simbolo

# %%
#Manip de los colores del gráf con el param colors
plt.pie(df['cant'],labels=df['etiquetas'], autopct='%1.1f%%',colors = ['b','y','g','orange']);#Le pasamos los colores en formato de lista, algunos con sus iniciales y otros escritos entero

# %%
#Agregamos sombras a nuestro gráf con el parám shadow activandolo con True
plt.pie(df['cant'],labels=df['etiquetas'], autopct='%1.1f%%',colors = ['b','y','g','orange'],shadow=True);

# %%
#Separamos una porcion de gráf para destacarla con el parám explode
plt.pie(df['cant'],labels=df['etiquetas'], autopct='%1.1f%%',colors = ['b','y','g','orange'],shadow=True,explode=(0,0,0,0.5));#Le tenemos que dar al parám la distancia de cada porcion y le dimo 0 al primero,0 al 2do, 0 al 3ero y 0.5 al cuarto

# %%
#Le metemos un título al gráfico con la fn .title()
plt.pie(df['cant'],labels=df['etiquetas'], autopct='%1.1f%%',colors = ['b','y','g','orange'],shadow=True,explode=(0,0,0,0.5));
plt.title('Frutas');#Le pasamos el nombre como argumento
# Out:
# Text(0.5, 1.0, 'Frutas')
