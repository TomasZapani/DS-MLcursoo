# %%
import matplotlib.pyplot as plt#Acá estamos importando la parte gráfica de la lib matplotlib(pyplot)
# %matplotlib inline#Esta línea reemplaza el uso de .show()

# %%
numeros = [2,9,4,5,6,7]#Creamos un conj random de datos para hacer la prueba

# %%
plt.plot(numeros)#Método para mostrar los datos en un gráf, le pasamos como arg la variable numeros
#plt.show()#Forma de gráficar
;
#Otra forma de graf

# %% [markdown]
# Una cosa a decir es que esta línea %matplotlib inline, reemplaza el uso de .show(), para usarla solo hay que colocarla y dps al final del todo el código hay colocar un ; para que muestre este gráfico, osea es lo mismo que .show() que tb hay que colocarlo al final del todo, solo que es una forma mas simple

# %%
#Guarda el gráf como arch
plt.savefig('Mi_gráf.jpg')#Con este método guardamos el gráfico que hicimos
