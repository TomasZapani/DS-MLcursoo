# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numeros = [2,9,4,5,6,7]#Creamos un conj random de datos para hacer la prueba

# %% [markdown]
# Formas de personalizar nuestro pared-figure-figura

# %%
plt.figure(facecolor='orange')#Así podemos personalizar nuestra figura, en este caso le estamos cambiando el color a naranja(podemos colocarle en ingles el color, el nro, hay varias) pero...


plt.plot(numeros)#Método para mostrar los datos en un gráf, le pasamos como arg la variable numeros
# Out:
# ''

# %% [markdown]
# Figura con mas de un gráfico-cuadro, subgráficos

# %%
plt.subplots(ncols = 2, nrows = 2)#Acá básicamente estamos desplegando 4gráf en simultáneo
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >]], dtype=object))

# %% [markdown]
# Vamos a capturar los elementos(figure y array) que nos dev el código de arriba por medio de una variable

# %%
#Captura mediante dos variables
fig, axs = plt.subplots(ncols=2,nrows=2)

# %%
type(fig)#Tipo de dato del elemento 1, será de tipo figure
# Out:
# matplotlib.figure.Figure

# %%
type(axs)#Tipo de dato del elemento 2, será un arrya
# Out:
# numpy.ndarray

# %% [markdown]
# Tomamos los dos 1eros elementos del array

# %%
axs[0]
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >], dtype=object)

# %% [markdown]
# Tomamos los dos 2dos elementos del array

# %%
axs[1]
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >], dtype=object)

# %% [markdown]
# Tomamos el 1ero elemento pero elegimos unicamente el 1ero de ese

# %%
axs[1][0]
# Out:
# <AxesSubplot: >

# %% [markdown]
# Que tipo de dato tienen los axes?AxesSubplot, es un tipo de dato de los axes

# %%
type(axs[0][0])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# Guardamos un axes en una variable y tenemos la posibilidade hacer distintas conf con sus elementos, como manejar su título, sus ejes de las y por ej, etc, etc, lo vamos a ir viendo

# %%
axs_1_2 = axs[1][0]
# Out:
# Text(0.5, 1.0, '')

# %%
axs_1_2.yaxis

# %%
axs_1_2.title
# Out:
# Text(0.5, 1.0, '')
