# %% [markdown]
# 📌 Pasos del Proyecto
# 1️⃣ Obtener y limpiar los datos
#
# Te voy a generar un dataset con ventas de una tienda de ropa ficticia.
# Vas a trabajar con Pandas y NumPy para limpiar los datos.
# 2️⃣ Análisis exploratorio con Pandas
#
# Filtrar ventas por mes y categoría (ejemplo: remeras, pantalones, zapatillas).
# Encontrar el producto más vendido y el que más ingresos generó.
# 3️⃣ Cálculos con NumPy
#
# Calcular los ingresos mensuales usando np.sum().
# Determinar el precio promedio de los productos vendidos.
# Ver la tendencia de precios usando np.mean() y np.median().
# 4️⃣ Conclusiones
#
# ¿Cuándo se vende más ropa?
# ¿Qué categoría de productos genera más ingresos?
# ¿Hay una tendencia de aumento/disminución de precios?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Datos_de_Ventas_de_Ropa.csv')
df.head(4)
# Out:
#         Fecha    Producto  Categoría  Cantidad  Precio Unitario  Total Venta
# 0  2024-04-12    Pantalón     Verano         1               35           35
# 1  2025-03-11     Vestido  Deportiva         3               50          150
# 2  2024-12-14  Zapatillas  Deportiva         3               80          240
# 3  2024-09-27    Pantalón   Invierno         1               35           35

# %% [markdown]
# 1_

# %%
#Transformamor la serie fecha a tipo datetime
df['Fecha'] =  pd.to_datetime(df['Fecha'])
type(df['Fecha'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#Creamos dentro del df una columna solo para mes
df['Mes']= df['Fecha'].dt.month

# %%
#Filtramos un mes específico
ventas_en_enero = df[df['Mes'] == 1]
ventas_en_enero
# Out:
#                             Fecha    Producto  Categoría  Cantidad  \
# 0   1970-01-01 00:00:00.000000004    Pantalón     Verano         1
# 1   1970-01-01 00:00:00.000000003     Vestido  Deportiva         3
# 2   1970-01-01 00:00:00.000000012  Zapatillas  Deportiva         3
# 3   1970-01-01 00:00:00.000000009    Pantalón   Invierno         1
# 4   1970-01-01 00:00:00.000000004    Pantalón     Casual         2
# ..                            ...         ...        ...       ...
# 495 1970-01-01 00:00:00.000000004        Buzo     Casual         4
# 496 1970-01-01 00:00:00.000000010     Vestido  Deportiva         3
# 497 1970-01-01 00:00:00.000000003      Remera     Casual         3
# 498 1970-01-01 00:00:00.000000012    Pantalón     Casual         2
# 499 1970-01-01 00:00:00.000000005    Pantalón     Casual         1
#
#      Precio Unitario  Total Venta  Mes
# 0                 35           35    1
# 1                 50          150    1
# 2                 80          240    1
# 3                 35           35    1
# 4                 35           70    1
# ..               ...          ...  ...
# 495               60          240    1
# 496               50          150    1
# 497               20           60    1
# 498               35           70    1
# 499               35           35    1
#
# [500 rows x 7 columns]

# %%
#Filtramos una categoría 
Verano = df[df['Categoría'] == 'Verano']
Verano
# Out:
#                             Fecha  Producto Categoría  Cantidad  \
# 0   1970-01-01 00:00:00.000000004  Pantalón    Verano         1
# 7   1970-01-01 00:00:00.000000001     Gorra    Verano         2
# 12  1970-01-01 00:00:00.000000011     Gorra    Verano         1
# 32  1970-01-01 00:00:00.000000004     Gorra    Verano         2
# 35  1970-01-01 00:00:00.000000009     Short    Verano         3
# ..                            ...       ...       ...       ...
# 482 1970-01-01 00:00:00.000000009   Campera    Verano         4
# 484 1970-01-01 00:00:00.000000005   Campera    Verano         1
# 485 1970-01-01 00:00:00.000000001     Gorra    Verano         1
# 490 1970-01-01 00:00:00.000000002      Buzo    Verano         2
# 494 1970-01-01 00:00:00.000000010     Gorra    Verano         1
#
#      Precio Unitario  Total Venta  Mes
# 0                 35           35    1
# 7                 15           30    1
# 12                15           15    1
# 32                15           30    1
# 35                25           75    1
# ..               ...          ...  ...
# 482              100          400    1
# 484              100          100    1
# 485               15           15    1
# 490               60          120    1
# 494               15           15    1
#
# [102 rows x 7 columns]

# %%
#Prod que hizo mas ventas 
Prod_más_vendido = df.groupby('Producto')['Total Venta'].max()
Prod_más_vendido.head(1)
# Out:
# Producto
# Buzo    240
# Name: Total Venta, dtype: int64

# %%
#Prod que más vendio
Prod_más_vendido = df.groupby('Producto')['Cantidad'].max()
Prod_más_vendido.head(1)
# Out:
# Producto
# Buzo    4
# Name: Cantidad, dtype: int64
